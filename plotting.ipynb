# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
hours=[2,3,4,5,6,7,8,10,12]

# %%
weight=[120,140,160,190,205,230,250,270,332]

# %%
health_index=[9,8.5,7,6.3,5.6,4.6,4,3.5,3]

# %%
plt.plot(hours,weight,'bo')
plt.xlabel('hours')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
plt.plot(hours,health_index,'ro')
plt.xlabel('hours')
plt.ylabel('health index')
# Out:
# Text(0, 0.5, 'health index')

# %%
time=[1,2,4,6,9]

# %%
water_mass=[3,5,10,12,15]

# %%
plt.plot(time,water_mass,'ko')
plt.xlabel('time')
plt.ylabel('water mass')
# Out:
# Text(0, 0.5, 'water mass')

# %%
team_names=["Chelsea","PSG","FC barcelona"]

# %%
team_scores=[2,10,3]

# %%
plt.bar(team_names,team_scores)
plt.ylabel("number of goals")
# Out:
# Text(0, 0.5, 'number of goals')
